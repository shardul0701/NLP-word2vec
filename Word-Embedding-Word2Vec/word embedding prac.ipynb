# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
voc_size=10000

# %%
onehot=[one_hot(word,voc_size) for word in sent]
print(onehot)
# Out:
# [[5508, 6359, 9850, 5796], [5508, 6359, 9850, 3], [5508, 5772, 9850, 8780], [929, 9222, 3927, 2966, 8670], [929, 9222, 3927, 2966, 3001], [3371, 5508, 2375, 9850, 7529], [6263, 3600, 4050, 2966]]

# %%
embed_size=8

# %%
dim=10

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
embed_matrix=pad_sequences(onehot,padding='pre',maxlen=embed_size)
embed_matrix
# Out:
# array([[   0,    0,    0,    0, 5508, 6359, 9850, 5796],
#        [   0,    0,    0,    0, 5508, 6359, 9850,    3],
#        [   0,    0,    0,    0, 5508, 5772, 9850, 8780],
#        [   0,    0,    0,  929, 9222, 3927, 2966, 8670],
#        [   0,    0,    0,  929, 9222, 3927, 2966, 3001],
#        [   0,    0,    0, 3371, 5508, 2375, 9850, 7529],
#        [   0,    0,    0,    0, 6263, 3600, 4050, 2966]])

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=embed_size))
model.compile('Adam','mse')

# %%
model.predict(embed_matrix)
# Out:
# array([[[-4.45300005e-02,  4.42551039e-02, -1.26200542e-02,
#          -2.98548471e-02, -6.20609522e-03, -2.53313426e-02,
#           2.38110460e-02, -2.05419548e-02,  3.43601741e-02,
#          -1.75678506e-02],
#         [-4.45300005e-02,  4.42551039e-02, -1.26200542e-02,
#          -2.98548471e-02, -6.20609522e-03, -2.53313426e-02,
#           2.38110460e-02, -2.05419548e-02,  3.43601741e-02,
#          -1.75678506e-02],
#         [-4.45300005e-02,  4.42551039e-02, -1.26200542e-02,
#          -2.98548471e-02, -6.20609522e-03, -2.53313426e-02,
#           2.38110460e-02, -2.05419548e-02,  3.43601741e-02,
#          -1.75678506e-02],
#         [-4.45300005e-02,  4.42551039e-02, -1.26200542e-02,
#          -2.98548471e-02, -6.20609522e-03, -2.53313426e-02,
#           2.38110460e-02, -2.05419548e-02,  3.43601741e-02,
#          -1.75678506e-02],
#         [ 3.50505225e-02,  2.89075114e-02,  2.42692940e-02,
#          -2.09429860e-02, -5.68120554e-03,  9.20711830e-03,
# ...

# %%
embed_matrix[0]
# Out:
# array([   0,    0,    0,    0, 5508, 6359, 9850, 5796])

# %%
model.predict(embed_matrix[0])
# Out:
# array([[[-4.4530001e-02,  4.4255104e-02, -1.2620054e-02, -2.9854847e-02,
#          -6.2060952e-03, -2.5331343e-02,  2.3811046e-02, -2.0541955e-02,
#           3.4360174e-02, -1.7567851e-02]],
#
#        [[-4.4530001e-02,  4.4255104e-02, -1.2620054e-02, -2.9854847e-02,
#          -6.2060952e-03, -2.5331343e-02,  2.3811046e-02, -2.0541955e-02,
#           3.4360174e-02, -1.7567851e-02]],
#
#        [[-4.4530001e-02,  4.4255104e-02, -1.2620054e-02, -2.9854847e-02,
#          -6.2060952e-03, -2.5331343e-02,  2.3811046e-02, -2.0541955e-02,
#           3.4360174e-02, -1.7567851e-02]],
#
#        [[-4.4530001e-02,  4.4255104e-02, -1.2620054e-02, -2.9854847e-02,
#          -6.2060952e-03, -2.5331343e-02,  2.3811046e-02, -2.0541955e-02,
#           3.4360174e-02, -1.7567851e-02]],
#
#        [[ 3.5050523e-02,  2.8907511e-02,  2.4269294e-02, -2.0942986e-02,
#          -5.6812055e-03,  9.2071183e-03, -4.2765774e-02, -1.8965328e-02,
#           9.4026811e-03,  1.0823980e-03]],
#
# ...
